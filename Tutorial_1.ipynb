# %% [markdown]
# <a href="https://colab.research.google.com/github/ajholstege/datascienceconcepts-tutorial/blob/main/Tutorial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1.  Google Colab Introduction
#
# ---

# %% [markdown]
# Each week, the tutorial sessions will involve <b>Python coding</b> in <b>Google Colab</b>.
#
# Python is a great general-purpose programming language on its own, but with the help of a few popular libraries <i>(e.g. numpy, pandas, matplotlib, seaborn, etc.)</i> it is transformed into a powerful environment for data science applications.
#
# If you've never done any Python before, or you've never heard of Google Colab - this tutorial will take you through all the basics and help you get ready for the weekly lab sessions.
#
# <br>
# This tutorial is also an ideal refresher for those of you who have previously completed a Python course, so please make sure you take the time to complete each of the practical challenges.

# %% [markdown]
# ### So... Welcome to Colab!
# Google Colab is a cloud-based platform that allows you to write and execute code in a web browser without requiring a local Python installation. Colab notebooks can contain live code, equations, visualizations and narrative text. Uses include data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more (you can read more at: <a href="https://colab.research.google.com/">colab.research.google.com</a>)
#
# <b>First, you should learn the anatomy of the Colab environment:</b><br>
# <img src='https://raw.githubusercontent.com/michhar/python-jupyter-notebooks/master/general/nb_diagram.png' alt="Jupyter" align="center">

# %% [markdown]
# <ul>
#     <li><b>Run Cell</b>: This runs the code in the selected cell. You can also press Shift+Enter to do this.</li>
#     <li><b>Choose Cell Type</b>: This will let you change the content type of the cell. 'Markdown' refers to a text only cell. This would be ideal for writing notes/comments. 'Code', as the name suggests, denotes that the cell will contain code (i.e. Python code).</li>
# </ul>
#
#
# ------
# <b>Other key points</b>:
# <ul>
#     <li>You can download the notebook you're working on - just go to File -> Download as, and there is a variety of download options (e.g. HTML, PDF)</li>
#     <li>Under Edit you can copy/cut/paste/merge and insert cells (just like in MS Excel)</li>
#     <li>If you press the Jupyter Logo at the top left, it will take you back to the home page where you can see a list of files within the working directory (i.e. the folder in which this file is stored).</li>
#     <li>The Kernel tab on the menu bar let's you interrupt the code you've executed. For example, if you try to perform an overly complex data visualisation and the notebook is loading for a long time, you can interrup, stop, restart and shutdown as needed.</li>
# </ul>
#
#
# ------

# %% [markdown]
# ### Downloading Practicals
#
# If you ever need to re-download the practical notebooks, you can do this by clicking "File" --> "Hub Control Panel". This should take you to a page with a "Download Notebooks" link. Clicking this will download new practical notebooks. Don't worry, it won't change anything that you've been working on that you've saved separately. Though if you ever feel like you want the original version of a notebook back, you can rename the notebook and click this link again to get the original version.
#
# ![](download_notebooks.png)

# %% [markdown]
# # Part 2.  Data Science Concepts
#
# Before we get stuck into Python, let's cover some of the basics of data science by exploring some data sources and answering some questions.

# %% [markdown]
# In this part, you will source a dataset, inspect the contents and understand the 'metadata'. We will also begin by considering some data science-focused questions.
#
#
# ## Data Sources and Asking interesting questions
# ------
#
# There are many trusted data repositories a Data Scientist can use for their research. For example, https://www.kaggle.com/, https://physionet.org/, https://disc.gsfc.nasa.gov/. In this example, you will focus on https://www.kaggle.com/.
#
#
# > 2.1. Go to https://www.kaggle.com/datasets/omarsobhy14/university-students-complaints-and-reports
#
#
# > 2.2. Look through the web page, please list 5 aspects of the dataset that a data scientist might reflect on relating to its contents and structure (for example, size, number of columns, data type(s), theme, country focus, etc.)
# ------

# %% [markdown]
# ------
# (double click to edit the text in a cell)
#
#
#
# ------

# %% [markdown]
# ------
# > 2.3. Do you think this dataset is structured or unstructured, and why?
# ------

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# ## Quantitative vs. Qualitative Data
#
# > 2.4. Download and open the University Students Complaints & Reports from Kaggle - press the Download button, then it may ask you to login/register an account with Kaggle.
#
# > 2.5 What format (file type) is the dataset?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# > 2.6. Open the file in MS Excel
#
#
# > 2.7. Please specify the quantitative data columns and qualitative data columns present in the table.

# %% [markdown]
# ------
# Quantiative data examples:
#
#
#
# Qualitative data examples:
#
# ------

# %% [markdown]
# > 2.8. Let's think deeper about the data, which columns can be considered Ordinal, Nominal, Categorical, Descrete or Continuous? Can some be considered as both?
#
# Here is a guide to help you think about it:
#
# <B>Ordinal - Categories that have ranks your can order (e.g., using the Likert Scale with a 5- or 7-point ordinal scale)
#
# <B>Categorical - when data can be divided into groups and ranked (e.g., race, age group).
#
# <B>Nominal - data that can be used for labels and not ranked (e.g., gender, nationality).
#
# <B>Descrete - Number-based, representing exact values.
#
# <B>Continuous - Used for precise measurements, often involving a decimal point.

# %% [markdown]
# ------
#
# Ordinal:
#
# Nominal:
#
# Categorical:
#
# Descrete:
#
# Continuous:
#
#
# ------

# %% [markdown]
# > 2.9. Spend a few moments scrolling through the rows of the dataset. Is there anything that stands out that you think needs removing to make the dataset easier to process?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# > 2.10. Would you consider this a big data set? Yes/No and why?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# > 2.11. Can we perform a regression calculation on the values of column "GPA" in the table? Why?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# > 2.12. Are there any columns that we could use for a cluster analysis?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# Let's consider some further Data Science questions listed in the 'Data Science Design Manual' book by Skiena (Chapter 1, p4).

# %% [markdown]
# > 2.13. What things might you be able to learn from this data set?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# > 2.14. What do you really want to know about the world, and how does this data set help you achieve this?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# > 2.15. What will it mean and to who (e.g., students union, or the dean, stakeholders) once you find out?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# # Part 3.  Python Basics
#
# Now we have some consider some basic questions a Data Scientist may like to ask, we will move on to learn tools that will help you answer these questions.
#
# Our focus is on Python and equipping you with the skills needed to process a data set and finding an answer to your research questions.
#
# Therefore, in this tutorial, we will cover the basics of Python code.
#
# As previously mentioned, you are not learning how to be software engineers or coders, the idea is to learn tools that can help you be data scientists. A basic understanding of Python can help with this, but we do not spend considerable time covering Python in detail.
#
# ![image.png](attachment:image.png)

# %%
# You can use a hash to type comments in the code.
# This is a comment
# etc....
# When you run code, the comments are ignored. They're just for us to add notes around the code.

# %%
# Alright, let's run our first code. The print() function prints out whatever is in the brackets.
print('Hello World')

# To run the code in this cell, you can press the "RUN" button on the toolbar at the top,
# or you can hit Shift+Enter on the keyboard.
# If you run this cell, the comments will be ignored and the code will be executed.
# Out:
# Hello World

# %% [markdown]
# ### Control flow
#
# Jupyter notebooks are made of cells (which can have code like the one above, or markdown content like this one). The order of execution of these cells is very important as that determines which variables are defined and what their current values are.
#
# If you take a look at the `In [ ]` part just before a code cell, there are multiple possible states it can be in:
#
# * `In [ ]` - Empty means this cell hasn't been run yet.
# * `In [*]` - A star indicates that this cell is still running
# * `In [n]` - A number means that the cell has finished running. These numbers start from 1 and increase every new cell that you run so you can use them to understand which cells have been run after which other cells.
#
# > 3.1. Rerun the print('Hello World') cell above. Does the number change?
#
# To understand the importance of order in a notebook, we'll do a small exercise below.
#
# > 3.2. First run the "print(variable)" cell below. What happens?

# %%
print(variable)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2118/3784293033.py in <cell line: 0>()
# ----> 1 print(variable)
#
# NameError: name 'variable' is not defined

# %% [markdown]
# > Python has pretty descriptive error messages. In most cases if something goes wrong, you should be able to tell what's causing the problem by reading the error.

# %% [markdown]
# > 3.3. Now run the "variable = 10" cell and run the "print(variable)" cell again. What's the output?

# %%
variable = 10

# %% [markdown]
# > 3.4. Run the "variable = 20" cell and the "print(variable)" cell. What's the output?

# %%
variable = 20

# %% [markdown]
# ### Variables
# A variable is a placeholder used to store one or more values. Instead of repeating these values in multiple places in your code, the variable holds the results of a calculation, database call, results of a database query, or other value. Some examples are below (you can call your variables pretty much anything):

# %%
Fruit = "Banana"
Vegetable = "Cucumber"
Numbers = [1, 2, 3, 4, 5]
print(Fruit)
print(Vegetable)
print(Numbers)
print(Fruit, Vegetable, Numbers)
# Out:
# Banana
# Cucumber
# [1, 2, 3, 4, 5]
# Banana Cucumber [1, 2, 3, 4, 5]

# %% [markdown]
# > 3.5. Create your own variable and print the result.

# %%
# Define variable


# Print it

# %% [markdown]
# ### Data types

# %% [markdown]
# #### Numbers

# %% [markdown]
# You will come across the terms <b>'Integers'</b> and <b>'Floating point numbers (floats)' </b> regularly. Integers are whole numbers like 1, 2, 3, 4, 5.... floats are numbers with a decimal, e.g. 1.1, 1.2, 1.3, 5.9, 99.9, 100.1 etc.

# %%
x = 3
print(x, type(x))
# Out:
# 3 <class 'int'>

# %%
print(x + 1)   # Addition;
print(x - 1)   # Subtraction;
print(x * 2)   # Multiplication;
print(x ** 2)  # Exponentiation;
# Out:
# 4
# 2
# 6
# 9

# %%
y = 2.5

print(type(y))
print(y, y + 1, y * 2, y ** 2)
# Out:
# <class 'float'>
# 2.5 3.5 5.0 6.25

# %% [markdown]
# #### Booleans
# Python implements all of the usual operators for Boolean logic, and uses English words like `and`, `or` and `not`:

# %%
true, false = True, False
print(type(true))
# Out:
# <class 'bool'>

# %%
print(true and false) # Logical AND;
print(true or false)  # Logical OR;
print(not true)   # Logical NOT;
# Out:
# False
# True
# False

# %% [markdown]
# #### Strings
# A string refers to 'text'. For example: 'hello world'. Numbers can also be written as string, for example '1, 2, 3, 4', however that would mean they are treated as text and you would be unable to treat them as numbers and perform calculations...

# %%
hello = 'hello'   # String literals can use single quotes
world = "world"   # or double quotes; it does not matter.
print(hello, len(hello))

# len() will tell you the length of the string
# Out:
# hello 5

# %%
hw = hello + ' ' + world  # String concatenation (i.e., putting strings together)
print(hw)
# Out:
# hello world

# %% [markdown]
# You can find a list of all string methods in the [documentation](https://docs.python.org/2/library/stdtypes.html#string-methods).

# %% [markdown]
# > 3.6. Define two strings of your own liking.

# %%
# Define strings
word1 =
word2 =

# Concatenate the strings yourself
sentence =
print(sentence)

# %% [markdown]
# ### Lists
# A list is an ordered, resizeable collection of elements which can be of different types.

# %%
xs = [3, 1, 2]   # This creates a list
print(xs)
# Out:
# [3, 1, 2]

# %%
ys = ['turkey', 'chicken', 'duck'] # it can be a collection of strings too
zs = [3, 'chicken', 2] # or a mixture of different data types
print(ys)
print(zs)
# Out:
# ['turkey', 'chicken', 'duck']
# [3, 'chicken', 2]

# %% [markdown]
# > 3.7. Create two of your own lists in the following cell, one called 'banana' the other called 'pancakes'

# %%
##add your two lists here in this cell
ys + zs

# %% [markdown]
# > 3.8. Can you concatenate the lists, i.e., add them together?

# %%
##add your code here

# %% [markdown]
# ### Indexing from Lists
# You can print out or select individual elements within a list using Indexing. To do this use the [  ] brackets next to the name of the variable you want to get the element from.
#
# Be aware that, in Python, <b>the index count starts at 0</b>. So in the xs variable example above, the element 3 is at location 0 in the list. This is <b>IMPORTANT</b> to remember.

# %%
#xs = [3, 1, 2]
print(xs[0])
print(xs[1])
print(xs[2])
print(xs[0], xs[2], xs[-1]) # If you have really long lists, you can use negative indices to count backwards from the end
# Out:
# 3
# 1
# 2
# 3 2 2

# %%
xs[2] = 'foo' # Lists can contain elements of different types. Here we are using indexing to replace the element 2 in the list.
print(xs)
# Out:
# [3, 1, 'foo']

# %%
xs.append('bar') # you can used .append() to add a new element to the end of the list
print(xs)
# Out:
# [3, 1, 'foo', 'bar']

# %% [markdown]
# > 3.9. Create your own list and try accessing the first element. Can you think of two different ways to do it?

# %%
# Create a list of your favorite foods
mylist =
# Print the first element

# %% [markdown]
# > 3.10. Now try adding at least two different data types to the list.

# %%
# Add entries to your list

# %% [markdown]
# #### Slicing
# In addition to accessing list elements one at a time, Python provides concise syntax to access sublists; this is known as slicing. Remember Python counts from 0.

# %%
nums = list(range(5))    # range is a built-in function that creates a list of integers
print(nums)
print(nums[2:4])    # Get a slice from index 2 to 4 (exclusive)
print(nums[2:])     # Get a slice from index 2 to the end
print(nums[:2])     # Get a slice from the start to index 2 (exclusive)
print(nums[:])      # Get a slice of the whole list
print(nums[:-1])    # Slice indices can be negative
nums[2:4] = [8, 9] # Assign a new sublist to a slice
print(nums)
# Out:
# [0, 1, 2, 3, 4]
# [2, 3]
# [2, 3, 4]
# [0, 1]
# [0, 1, 2, 3, 4]
# [0, 1, 2, 3]
# [0, 1, 8, 9, 4]

# %% [markdown]
# > 3.11. Get the last two elements of your previously defined list.

# %%
#add your code here

# %% [markdown]
# > 3.12. Change the second and third element of your list. Print the result.

# %%
#add your code here

# %% [markdown]
# ### Loops

# %%
#You can loop over the elements of a list like this:
animals = ['cat', 'dog', 'monkey']
for i in animals:
    print(i)
# Out:
# cat
# dog
# monkey

# %% [markdown]
# If you want access to the index of each element within the body of a loop, use the built-in enumerate function. Remember, Python numbering starts from 0.

# %% [markdown]
# > 3.13. Create your own list then create a loop to print out all the elements

# %%
#add your code here
for index, item in enumerate(animals):
    print(index, item)
# Out:
# 0 cat
# 1 dog
# 2 monkey

# %% [markdown]
# ### Conditionals
#
# `if`, `elif`, and `else` allow for checking if a variable satisfies a certain condition and perform different operations based on this comparison.

# %%
match = 2

if match == 0:
    print("Bye")
elif match == 1:
    print("Keep going")
elif match == 2:
    print("Hello!")
else:
    print("Match must be 0, 1, or 2")
# Out:
# Hello!

# %% [markdown]
# > 3.14. Change the value of `match` above and rerun the cell to see what happens to the output.

# %% [markdown]
# ### Functions

# %% [markdown]
# Functions in programming languages allow you to encapsulate a piece of code such that you can use it in different places with different inputs without having to type in all the code again and again. Python functions are defined using the 'def' keyword. For example:

# %%
def sign(x):
    if x > 0:
        return 'positive'
    elif x < 0:
        return 'negative'
    else:
        return 'zero'

# %%
for x in [-1, 0, 1]:
    print(sign(x))
# Out:
# negative
# zero
# positive

# %%
#We will often define functions to take optional keyword arguments, like this:
def hello(name, loud=False):
    if loud:
        print(f'HELLO, {name.upper()}')
    else:
        print(f'Hello, {name}!')

hello('Bob')
hello('Fred', loud=True)
# Out:
# Hello, Bob!
# HELLO, FRED

# %% [markdown]
# > 3.15. What do you think upper() does in the above code?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %% [markdown]
# > 3.16. Create your own function that when called prints out "Hello world!"

# %%
# Define the function



# Call out the function

# %% [markdown]
# ### Classes
#
# A class takes the function concept one step further. It allows you to neatly encapsulate a collection of data and functions together. Let's look at an example:

# %%
import numpy as np
class Circle:
    # The "constructor" - creates an instance of this class
    def __init__(self, radius, center_x, center_y):
        self.radius = radius
        self.center_x = center_x
        self.center_y = center_y

    def get_area(self):
        return np.pi * self.radius ** 2

    def get_circumference(self):
        return 2 * np.pi * self.radius

    def translate(self, move_x, move_y):
        self.center_x += move_x
        self.center_y += move_y

    def scale(self, percentage):
        self.radius += self.radius * percentage/100

    def print_class(self):
        print(f"Radius: {self.radius}")
        print(f"Center: ({self.center_x}, {self.center_y})")

# %% [markdown]
# Now we can define an instance of this class, get information from it, and perform operations on it.

# %%
my_circle = Circle(radius=5, center_x=0, center_y=0) # or my_circle = Circle(5, 0, 0)
my_circle.print_class()
# Out:
# Radius: 5
# Center: (0, 0)

# %% [markdown]
# # Part 4. Importing Data to Jupyter Notebook
# To find meaning from our University Complaints data set, we would ideally like to import it to Jupyter notebook and then use Python code to explore the contents.
#
# To import the data we will use a Python library called Pandas. More on Python libraries are covered in the lectures and in next the tutorials next week. For now, you can think of a library as a collection of existing Python code that we can call using short commands that allow us to manipulate the dataset without writing lots of our own code.

# %%
#to use Pandas, we first have to import the library so that Jupyter knows that we want to use it
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import our spreadsheet into Jupyter. Inside the '' you will need to add the location of the data set you downloaded to
#your laptop from Kaggle
df = pd.read_csv('...')
#for example, mine is saved here C:/Users/hurst001/Downloads/UniComplaints.csv, so my code would be
#df = pd.read_csv('C:/Users/hurst001/Downloads/UniComplaints.csv')
#this code reads the data in as a data frame.
#a data frame is a two-dimensional table-like data structure that can hold data of different types, we will use
#this format a lot in our work

# %%
#print out the first few rows of the dataset using the head() function
df.head()
# Out:
#                             Genre  \
# 0  Academic Support and Resources
# 1  Academic Support and Resources
# 2  Academic Support and Resources
# 3  Academic Support and Resources
# 4  Academic Support and Resources
#
#                                              Reports  Age   Gpa  Year  Count  \
# 0  The limited access to research databases and m...   27  2.18     2      1
# 1  I'm having trouble finding the course material...   23  3.11     2      1
# 2  It's frustrating to have limited access to res...   20  3.68     2      1
# 3  I'm really struggling in one of my classes but...   20  1.30     2      1
# 4   I am really struggling with understanding the...   26  2.50     2      1
#
#   Gender Nationality
# 0      M       Egypt
# 1      F       Egypt
# 2      F       Egypt
# 3      F       Egypt
# 4      F       Egypt

# %%
#we can create some quick plots to help us visually inspect the data.
#for example, here we create a plot of the Gpa column
df['Gpa'].plot()
# Out:
# <Axes: >

# %% [markdown]
# > 4.1. Try replacting 'Gpa' with some of the other columns one at a time, what happens?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %%
#we can also use pandas for more complex plots, such as a scatter plot
#below we plot the Age against the Gpa
df.plot.scatter(x='Age', y='Gpa')
# Out:
# <Axes: xlabel='Age', ylabel='Gpa'>

# %% [markdown]
# > 4.2. What type of information can we now quickly notice about the data set by creating plots such as these?

# %% [markdown]
# ------
#
# Answer:
#
# ------

# %%
#have a look at the official Pandas reference document and try out some different plots
#use this website address:  https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %% [markdown]
# > 4.3. Do you think that plot type can affect our interpretation of the data and why?

# %% [markdown]
# ------
#
# Answer:
#
# ------
